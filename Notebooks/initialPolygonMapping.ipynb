# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from pprint import pprint
from datetime import date, timedelta, datetime
import requests
import xarray as xr
import rioxarray
from shapely.geometry import mapping

import earthaccess

# %%
df = pd.read_csv('../agg_data.csv')

# %%
df['Common name'].nunique()
# Out:
# 530

# %%
fish = list(df[df['Commercial status']=='highly commercial']['Common name'])

# %%
display(df['Oceanographic province'].value_counts().sort_index())
# Out:
# AUSE        3
# AUSW        2
# BPRL        3
# BRAZ       22
# CAMR        5
# CARB       17
# CCAL       17
# CHIL        5
# CHIN      117
# CNRY        1
# EAFR       15
# FKLD        3
# GFST       19
# GUIA       54
# GUIN        3
# HUMB        7
# INDE        5
# INDW        3
# KURO        1
# MEDI      131
# NAST E     29
# NECS      111
# NPSE        7
# NPTG       43
# NWCS        5
# REDS       30
# SPSG       63
# SUND       55
# TASM       24
# WTRA        1
# Name: Oceanographic province, dtype: int64

# %%
df['Oceanographic province'].nunique()
# Out:
# 30

# %%
longhurst = gpd.read_file('../Savoca/Longhurst_world_v4_2010.shp')

# %%
longhurst
# Out:
#    ProvCode                                          ProvDescr  \
# 0      BPLR               Polar - Boreal Polar Province (POLR)
# 1      ARCT                   Polar - Atlantic Arctic Province
# 2      SARC                Polar - Atlantic Subarctic Province
# 3      NADR     Westerlies - N. Atlantic Drift Province (WWDR)
# 4      GFST                  Westerlies - Gulf Stream Province
# 5      NASW  Westerlies - N. Atlantic Subtropical Gyral Pro...
# 6      NATR  Trades - N. Atlantic Tropical Gyral Province (...
# 7      WTRA        Trades - Western Tropical Atlantic Province
# 8      ETRA        Trades - Eastern Tropical Atlantic Province
# 9      SATL      Trades - South Atlantic Gyral Province (SATG)
# 10     NECS             Coastal - NE Atlantic Shelves Province
# 11     CNRY           Coastal - Canary Coastal Province (EACB)
# 12     GUIN          Coastal - Guinea Current Coastal Province
# 13     GUIA                 Coastal - Guianas Coastal Province
# 14     NWCS             Coastal - NW Atlantic Shelves Province
# 15     MEDI  Westerlies - Mediterranean Sea, Black Sea Prov...
# 16     CARB                        Trades - Caribbean Province
# 17     NASE  Westerlies - N. Atlantic Subtropical Gyral Pro...
# 18     BRAZ          Coastal - Brazil Current Coastal Province
# 19     FKLD             Coastal - SW Atlantic Shelves Province
# 20     BENG        Coastal - Benguela Current Coastal Province
# 21     MONS             Trades - Indian Monsoon Gyres Province
# 22     ISSG       Trades - Indian S. Subtropical Gyre Province
# 23     EAFR               Coastal - E. Africa Coastal Province
# 24     REDS           Coastal - Red Sea, Persian Gulf Province
# 25     ARAB            Coastal - NW Arabian Upwelling Province
# 26     INDE                Coastal - E. India Coastal Province
# 27     INDW                Coastal - W. India Coastal Province
# 28     AUSW     Coastal - Australia-Indonesia Coastal Province
# 29     BERS         Polar - N. Pacific Epicontinental Province
# 30     PSAE  Westerlies - Pacific Subarctic Gyres Province ...
# 31     PSAW  Westerlies - Pacific Subarctic Gyres Province ...
# 32     KURO             Westerlies - Kuroshio Current Province
# 33     NPPF       Westerlies - N. Pacific Polar Front Province
# 34     NPSW  Westerlies - N. Pacific Subtropical Gyre Provi...
# 35     TASM                   Westerlies - Tasman Sea Province
# 36     SPSG  Westerlies - S. Pacific Subtropical Gyre Province
# 37     NPTG         Trades - N. Pacific Tropical Gyre Province
# 38     PNEC  Trades - N. Pacific Equatorial Countercurrent ...
# 39     PEQD    Trades - Pacific Equatorial Divergence Province
# 40     WARM             Trades - W. Pacific Warm Pool Province
# 41     ARCH         Trades - Archipelagic Deep Basins Province
# 42     ALSK      Coastal - Alaska Downwelling Coastal Province
# 43     CCAL    Coastal - California Upwelling Coastal Province
# 44     CAMR        Coastal - Central American Coastal Province
# 45     CHIL      Coastal - Chile-Peru Current Coastal Province
# 46     CHIN               Coastal - China Sea Coastal Province
# 47     SUND           Coastal - Sunda-Arafura Shelves Province
# 48     AUSE         Coastal - East Australian Coastal Province
# 49     NEWZ             Coastal - New Zealand Coastal Province
# 50     SSTC   Westerlies - S. Subtropical Convergence Province
# 51     SANT                 Westerlies - Subantarctic Province
# 52     ANTA                         Polar - Antarctic Province
# 53     APLR                     Polar - Austral Polar Province
#
#                                              geometry
# 0   MULTIPOLYGON (((-161.18426 63.5, -161.5 63.5, ...
# 1   MULTIPOLYGON (((-21.51305 64.64409, -21.55945 ...
# 2   MULTIPOLYGON (((11.26472 63.96082, 11.09548 63...
# 3   POLYGON ((-11.5 57.5, -11.5 56.5, -11.5 55.5, ...
# 4   POLYGON ((-43.5 43.5, -43.5 42.5, -43.5 41.5, ...
# 5   POLYGON ((-39.5 25.5, -40.5 25.5, -41.5 25.5, ...
# 6   MULTIPOLYGON (((-72.34673 18.53597, -72.36877 ...
# 7   POLYGON ((-19.5 -6.5, -20.5 -6.5, -21.5 -6.5, ...
# 8   POLYGON ((9.5 -12.5, 8.5 -12.5, 7.5 -12.5, 6.5...
# 9   POLYGON ((-19.5 -6.5, -18.5 -6.5, -17.5 -6.5, ...
# 10  POLYGON ((10.97944 54.38056, 10.99458 54.37749...
# 11  MULTIPOLYGON (((-16.33947 11.5, -16.38454 11.5...
# 12  MULTIPOLYGON (((-15.42389 11.67611, -15.42931 ...
# 13  MULTIPOLYGON (((-35.5 -3.5, -35.5 -4.5, -34.5 ...
# 14  MULTIPOLYGON (((-82.46584 27.73291, -82.5 27.6...
# 15  MULTIPOLYGON (((34.98966 29.5, 34.91623 29.5, ...
# 16  POLYGON ((-82.5 27.95346, -82.5 27.6951, -82.5...
# 17  POLYGON ((-19.5 25.5, -20.5 25.5, -21.5 25.5, ...
# 18  POLYGON ((-33.5 -10.5, -33.5 -11.5, -33.5 -12....
# 19  MULTIPOLYGON (((-68.9932 -54.43104, -68.99487 ...
# 20  POLYGON ((11.71697 -17.5, 11.71639 -17.53917, ...
# 21  MULTIPOLYGON (((80.61033 9.44472, 80.56945 9.4...
# 22  POLYGON ((117.5 -16.5, 117.5 -17.5, 117.5 -18....
# 23  POLYGON ((48.50315 -13.5, 48.50388 -13.51555, ...
# 24  MULTIPOLYGON (((34.57215 28.0959, 34.62478 28....
# 25  MULTIPOLYGON (((39.5 -7.5, 39.28814 -7.5, 39.2...
# 26  POLYGON ((97.93498 14.5, 97.5 14.5, 96.5 14.5,...
# 27  MULTIPOLYGON (((80.5 9.5, 80.5 9.47885, 80.493...
# 28  MULTIPOLYGON (((125.66081 -14.61166, 125.64224...
# 29  MULTIPOLYGON (((126.68849 37.83391, 126.68054 ...
# 30  POLYGON ((-134.5 50.5, -134.5 49.5, -134.5 48....
# 31  MULTIPOLYGON (((148.54026 45.44777, 148.46051 ...
# 32  MULTIPOLYGON (((124.74987 10.5, 124.5 10.5, 12...
# 33  MULTIPOLYGON (((156.5 34.5, 155.5 34.5, 155.5 ...
# 34  MULTIPOLYGON (((-175.5 28.5, -175.5 27.5, -175...
# 35  MULTIPOLYGON (((174.5 -35.89155, 174.5 -35.994...
# 36  MULTIPOLYGON (((174.79553 -37.02306, 174.88748...
# 37  POLYGON ((-114.5 16.5, -114.5 15.5, -114.5 14....
# 38  POLYGON ((-82.5 0.5, -83.5 0.5, -84.5 0.5, -85...
# 39  POLYGON ((-86.5 0.5, -86.5 -0.5, -86.5 -1.5, -...
# 40  MULTIPOLYGON (((-175.5 1.5, -175.5 0.5, -175.5...
# 41  MULTIPOLYGON (((128.69141 -3.50004, 128.67804 ...
# 42  MULTIPOLYGON (((-127.5 50.5868, -127.5 50.5627...
# 43  MULTIPOLYGON (((-110.5 24.5, -110.5 24.22013, ...
# 44  MULTIPOLYGON (((-80.44239 -0.5, -80.5 -0.5, -8...
# 45  POLYGON ((-80.5 -0.37114, -80.50118 -0.37257, ...
# 46  MULTIPOLYGON (((128.5 35.12007, 128.5 35.01085...
# 47  MULTIPOLYGON (((113.67269 -8.5, 113.5 -8.5, 11...
# 48  POLYGON ((154.5 -33.5, 154.5 -34.5, 154.5 -35....
# 49  MULTIPOLYGON (((168.56387 -46.58466, 168.55164...
# 50  MULTIPOLYGON (((180 -41.5, 179.5 -41.5, 179.5 ...
# 51  MULTIPOLYGON (((-69.16417 -54.51973, -69.14903...
# 52  POLYGON ((180 -57.5, 180 -67.5, 179.5 -67.5, 1...
# 53  MULTIPOLYGON (((-83.5 -78.5, -83.71472 -78.5, ...

# %%
def getSatelliteData(input_date):
    '''
    perform url request to earthdata cmr for CYGNSS, RSSSMAP, and GHRSST data and return the data
    from the most recent 30 days 
    '''
    
    if not isinstance(input_date, date):
        raise TypeError("This function only accepts date objects.")
    
    # define earthdata cmr url
    earthdata_url = 'https://cmr.earthdata.nasa.gov/search/granules.umm_json?collection_concept_id='
    
    # login to earthdata portal to get credentials
    auth = earthaccess.login()
    
    # define concept ids for desired data
    cygnss_concept_id = 'C2893924134-POCLOUD' # microplastic
    rsssmap_concept_id = 'C2832227567-POCLOUD' # sea surface salinity
    ghrsst_concept_id = 'C2600797908-POCLOUD' # sea surface temperature

    # define time range to search [days]
    temporal_range = 30
    
    # calculate start data from input date
    start_date = (input_date - timedelta(days=temporal_range)).strftime('%Y-%m-%dT%H:%M:%SZ')
    
    # format and combine start date and input date for url query parameter
    temporal_query = start_date + ',' + input_date.strftime('%Y-%m-%dT%H:%M:%SZ')

    # send search request to cmr with additional params
    cygnss_r = requests.get(earthdata_url + cygnss_concept_id + '&temporal=' + temporal_query + '&pageSize=1000')
    ghrsst_r = requests.get(earthdata_url + ghrsst_concept_id + '&temporal=' + temporal_query + '&pageSize=1000')
    
    # re-define time range [days] to search for RSSSMAP data because it is an 8 day average
    temporal_range = 30 - 4
    
    # calculate start data from input date
    start_date = (input_date - timedelta(days=temporal_range)).strftime('%Y-%m-%dT%H:%M:%SZ')
    
    # format and combine start date and input date for url query parameter
    temporal_query = start_date + ',' + input_date.strftime('%Y-%m-%dT%H:%M:%SZ')
    
    rsssmap_r = requests.get(earthdata_url + rsssmap_concept_id + '&temporal=' + temporal_query + '&pageSize=1000')
    
    # aggregate data responses for pulling urls
    data_r = [('CYGNSS',cygnss_r), ('RSSSMAP',rsssmap_r), ('GHRSST',ghrsst_r)]
    
    # if the resonse is good, parse through and print it
    data_files = {key : [] for key, _ in data_r}
    for data_name, r in data_r:
        if r.ok:
            response_body = r.json()
            for itm in response_body['items']:
                for urls in itm['umm']['RelatedUrls']:
                    if 'OPeNDAP' in urls['Description']:
                        data_files[data_name].append(urls['URL'])
                    
    return data_files

# %%
data_collection_date = date(2016, 7, 1)
data_collection_date = date(2024, 10, 14)

# %%
satellite_files = getSatelliteData(data_collection_date)
pprint(satellite_files)
# Out:
# {'CYGNSS': ['https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240914-120000-e20240914-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240915-120000-e20240915-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240916-120000-e20240916-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240917-120000-e20240917-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240918-120000-e20240918-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240919-120000-e20240919-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240920-120000-e20240920-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240921-120000-e20240921-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240922-120000-e20240922-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240923-120000-e20240923-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240924-120000-e20240924-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240925-120000-e20240925-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240926-120000-e20240926-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240927-120000-e20240927-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240928-120000-e20240928-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240929-120000-e20240929-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20240930-120000-e20240930-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20241001-120000-e20241001-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20241002-120000-e20241002-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20241003-120000-e20241003-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20241004-120000-e20241004-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20241005-120000-e20241005-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20241006-120000-e20241006-120000.l3.grid-microplastic.a32.d33',
#             'https://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/cyg.ddmi.s20241007-120000-e20241007-120000.l3.grid-microplastic.a32.d33'],
#  'GHRSST': ['https://opendap.earthdata.nasa.gov/collections/C2600797908-POCLOUD/granules/20240914000000-REMSS-L3U_GHRSST-SSTsubskin-AMSR2-RSS_AMSR2_ocean_L3_daily_2024-09-14_v08.2-rt-v02.0-fv01.0',
#             'https://opendap.earthdata.nasa.gov/collections/C2600797908-POCLOUD/granules/20240915000000-REMSS-L3U_GHRSST-SSTsubskin-AMSR2-RSS_AMSR2_ocean_L3_daily_2024-09-15_v08.2-rt-v02.0-fv01.0',
#             'https://opendap.earthdata.nasa.gov/collections/C2600797908-POCLOUD/granules/20240926000000-REMSS-L3U_GHRSST-SSTsubskin-AMSR2-RSS_AMSR2_ocean_L3_daily_2024-09-26_v08.2-rt-v02.0-fv01.0',
#             'https://opendap.earthdata.nasa.gov/collections/C2600797908-POCLOUD/granules/20240927000000-REMSS-L3U_GHRSST-SSTsubskin-AMSR2-RSS_AMSR2_ocean_L3_daily_2024-09-27_v08.2-rt-v02.0-fv01.0',
#             'https://opendap.earthdata.nasa.gov/collections/C2600797908-POCLOUD/granules/20240928000000-REMSS-L3U_GHRSST-SSTsubskin-AMSR2-RSS_AMSR2_ocean_L3_daily_2024-09-28_v08.2-rt-v02.0-fv01.0',
#             'https://opendap.earthdata.nasa.gov/collections/C2600797908-POCLOUD/granules/20240929000000-REMSS-L3U_GHRSST-SSTsubskin-AMSR2-RSS_AMSR2_ocean_L3_daily_2024-09-29_v08.2-rt-v02.0-fv01.0',
#             'https://opendap.earthdata.nasa.gov/collections/C2600797908-POCLOUD/granules/20240930000000-REMSS-L3U_GHRSST-SSTsubskin-AMSR2-RSS_AMSR2_ocean_L3_daily_2024-09-30_v08.2-rt-v02.0-fv01.0',
#             'https://opendap.earthdata.nasa.gov/collections/C2600797908-POCLOUD/granules/20241001000000-REMSS-L3U_GHRSST-SSTsubskin-AMSR2-RSS_AMSR2_ocean_L3_daily_2024-10-01_v08.2-rt-v02.0-fv01.0'],
#  'RSSSMAP': ['https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_258_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_259_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_260_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_261_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_262_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_263_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_264_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_265_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_266_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_267_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_268_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_269_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_270_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_271_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_272_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_273_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_274_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_275_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_276_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_277_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_278_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_279_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_280_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_281_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_282_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_283_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_284_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_285_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_287_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_288_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_289_FNL_v06.0',
#              'https://opendap.earthdata.nasa.gov/collections/C2832227567-POCLOUD/granules/RSS_smap_SSS_L3_8day_running_2024_290_FNL_v06.0']}

# %%
import requests
from pydap.client import open_url, open_dap_file, open_file
edl_token = "eyJ0eXAiOiJKV1QiLCJvcmlnaW4iOiJFYXJ0aGRhdGEgTG9naW4iLCJzaWciOiJlZGxqd3RwdWJrZXlfb3BzIiwiYWxnIjoiUlMyNTYifQ.eyJ0eXBlIjoiVXNlciIsInVpZCI6IncyMzNkZXJtYW4iLCJleHAiOjE3MzUyODIxNDksImlhdCI6MTczMDA5ODE0OSwiaXNzIjoiaHR0cHM6Ly91cnMuZWFydGhkYXRhLm5hc2EuZ292In0.yGh2xziXJ4V7PDitUyFSLKi-IWvVFUG-QylNj0rmEMUkYDwNnCzu2ecA2duk2IKYC5XxIuOLGub9EHLppavZkEKmBP0nTKGEs12hUxRLiPf_1DFDayCwy786jr8T61XshSo1Y79ZyDfku3ZoDQzE2Ir74b-wGbRFVJnl5XwLz10ABNw5I5jNxe1u1oDNFsztaK4C6QmoKEdbZPY5KZ0-nzJUh0kkDxl0VXCrkqjIUtbRt6y_e-Sxi_o_x0JEyM9Le4-fekFwnA3tBXbQjcc0N0sSSF4ZzqJ6Bq5PbJ13cDj8yMRV2h_u5Oe7Ys_6LK76OLOsgNvz4ER_Hios0OwRhg"

auth_hdr="Bearer " + edl_token

# pass Token Authorization to a new Session.

my_session = requests.Session()
my_session.headers={"Authorization": auth_hdr}
dataset_url = "dap4://opendap.earthdata.nasa.gov/collections/C2893924134-POCLOUD/granules/"
ds = open_url(dataset_url, session=my_session, protocol='dap4')
ds.tree()
# Out:
# .cyg.ddmi.s20180816-120000-e20180816-120000.l3.grid-microplastic.a32.d33.nc
# ├──lat
# ├──lon
# ├──time
# ├──stddev_mp_samples
# ├──num_mp_samples
# └──mp_concentration

# %%
# takes ~5 minutes to load in a months worth of data
tic = datetime.now()
#mp_satellite_data = [satellite_files['CYGNSS'][0]]
mp_satellite_data = [file.replace('https','dap4') for file in satellite_files['CYGNSS']]
mp_sat_data = xr.open_mfdataset([mp_satellite_data[0]], combine='by_coords', engine='pydap')
print(f'Loading satellite data took {(datetime.now() - tic).total_seconds()} seconds\n')
# Out:
# Loading satellite data took 19.328134 seconds

# %%
mp_sat_data
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 1, lat: 297, lon: 1440)
# Coordinates:
#   * time               (time) datetime64[ns] 2024-09-14T12:00:00
#   * lat                (lat) float32 -37.0 -36.75 -36.5 ... 36.5 36.75 37.0
#   * lon                (lon) float32 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
# Data variables:
#     mp_concentration   (time, lat, lon) float32 dask.array<chunksize=(1, 297, 1440), meta=np.ndarray>
#     num_mp_samples     (time, lat, lon) float64 dask.array<chunksize=(1, 297, 1440), meta=np.ndarray>
#     stddev_mp_samples  (time, lat, lon) float32 dask.array<chunksize=(1, 297, 1440), meta=np.ndarray>
# Attributes:
#     build_dmrpp:    3.21.0-46
#     bes:            3.21.0-46
#     libdap:         libdap-3.21.0-27
#     configuration:  \n# TheBESKeys::get_as_config()\nAllowedHosts=^https?:\/\...
#     invocation:     build_dmrpp -c /tmp/bes_conf_yD4K -f /tmp/tmpwloem11s//cy...

# %%
if mp_sat_data.rio.crs is not None:
    print(f"Dataset CRS: {mp_sat_data.rio.crs}")
else:
    print("Dataset CRS is not set.")
# Out:
# Dataset CRS: EPSG:4326

# %%
mp_sat_data = mp_sat_data.rio.write_crs("EPSG:4326", inplace=True)

# %%
mp_sat_data = mp_sat_data.assign_coords(lon=(((mp_sat_data.lon + 180) % 360) - 180)).sortby('lon')

# %%
mp_sat_data = mp_sat_data.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)

# %%
longhurst = longhurst.cx[:, -37.0:37.0]

# %%
aggregated_results = []

for _, polygon in longhurst.iterrows():
    print('Starting polygon #',_)
    # Mask the dataset by the current polygon
    masked_ds = mp_sat_data.rio.clip([mapping(polygon.geometry)], mp_sat_data.rio.crs, drop=True)
    
    # Aggregate (e.g., mean concentration within the polygon)
    mean_concentration = masked_ds['mp_concentration'].mean(dim=['lat', 'lon'], skipna=True)
    aggregated_results.append(mean_concentration.values)

# Convert results to a DataFrame for easier viewing or further analysis
aggregated_df = pd.DataFrame({
    'region': longhurst['ProvCode'],  # Replace with the appropriate column name for regions
    'mean_concentration': aggregated_results
})
# Out:
# Starting polygon # 4
# Starting polygon # 5
# Starting polygon # 6
# Starting polygon # 7
# Starting polygon # 8
# Starting polygon # 9
# Starting polygon # 11
# Starting polygon # 12
# Starting polygon # 13
# Starting polygon # 14
# Starting polygon # 15
# Starting polygon # 16
# Starting polygon # 17
# Starting polygon # 18
# Starting polygon # 20
# Starting polygon # 21
# Starting polygon # 22
# Starting polygon # 23
# Starting polygon # 24
# Starting polygon # 25
# Starting polygon # 26
# Starting polygon # 27
# Starting polygon # 28
# Starting polygon # 29
# Starting polygon # 32
# Starting polygon # 33
# Starting polygon # 34
# Starting polygon # 35
# Starting polygon # 36
# Starting polygon # 37
# Starting polygon # 38
# Starting polygon # 39
# Starting polygon # 40
# Starting polygon # 41
# Starting polygon # 43
# Starting polygon # 44
# Starting polygon # 45
# Starting polygon # 46
# Starting polygon # 47
# Starting polygon # 48
# Starting polygon # 49
# Starting polygon # 50

# %%
aggregated_df
# Out:
#    region mean_concentration
# 4    GFST        [12977.907]
# 5    NASW        [13373.339]
# 6    NATR        [13470.038]
# 7    WTRA        [13369.679]
# 8    ETRA        [13521.399]
# 9    SATL        [12640.312]
# 11   CNRY        [13456.916]
# 12   GUIN        [14280.075]
# 13   GUIA       [13472.9795]
# 14   NWCS        [13102.434]
# 15   MEDI         [13457.91]
# 16   CARB        [13486.874]
# 17   NASE        [13256.998]
# 18   BRAZ         [13226.19]
# 20   BENG        [12598.339]
# 21   MONS        [12931.952]
# 22   ISSG        [12479.986]
# 23   EAFR        [12865.567]
# 24   REDS        [13007.869]
# 25   ARAB        [13183.925]
# 26   INDE        [12876.297]
# 27   INDW        [13858.709]
# 28   AUSW        [12958.273]
# 29   BERS        [13409.439]
# 32   KURO        [12949.088]
# 33   NPPF       [13211.8125]
# 34   NPSW        [13085.244]
# 35   TASM        [12870.518]
# 36   SPSG        [12797.709]
# 37   NPTG       [12823.0625]
# 38   PNEC        [12902.522]
# 39   PEQD        [13080.881]
# 40   WARM        [13228.662]
# 41   ARCH         [12977.74]
# 43   CCAL        [13084.322]
# 44   CAMR        [13414.984]
# 45   CHIL        [13179.349]
# 46   CHIN        [13001.338]
# 47   SUND        [13436.695]
# 48   AUSE        [13136.619]
# 49   NEWZ        [12611.958]
# 50   SSTC        [12719.768]

# %%
print(longhurst.total_bounds) # Returns [minx, miny, maxx, maxy]
# Out:
# [-180.          -78.50015648  180.           90.00000191]

# %%
print(f"Latitude range: {mp_sat_data.lat.min().values} to {mp_sat_data.lat.max().values}")
print(f"Longitude range: {mp_sat_data.lon.min().values} to {mp_sat_data.lon.max().values}")
# Out:
# Latitude range: -37.0 to 37.0
# Longitude range: -180.0 to 179.75
